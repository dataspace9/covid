# %%
import pandas as pd
import numpy as np
from pandas import DataFrame as df
from datetime import datetime
import matplotlib
from matplotlib import pyplot as plt

# %%
folder = "c:/PY-ML/data/covid2405/"
vaccine_file = folder + "vaccine_doses_statewise.csv"

# %%
vaccine_data = pd.read_csv(vaccine_file)

# %%
vaccine_data = df(vaccine_data)

# %%
vaccine_data
# Out:
#                                        State  16/01/2021  18/01/2021  \
# 0                Andaman and Nicobar Islands         225         442
# 1                             Andhra Pradesh       18412       46680
# 2                          Arunachal Pradesh         829        2805
# 3                                      Assam        3528        5542
# 4                                      Bihar       18169       33389
# 5                                 Chandigarh         265         265
# 6                               Chhattisgarh        5592       10872
# 7   Dadra and Nagar Haveli and Daman and Diu         123         123
# 8                                      Delhi        4319        7968
# 9                                        Goa         426         426
# 10                                   Gujarat       10787       10787
# 11                                   Haryana        5589       17642
# 12                          Himachal Pradesh        1517        4817
# ...

# %%
vaccine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Columns: 130 entries, State to 25/05/2021
# dtypes: int64(129), object(1)
# memory usage: 38.7+ KB

# %%
vax_list = vaccine_data.columns

# %%
x = 1
while x < 129:
    vaccine_data[x] = vaccine_data[vax_list[x + 1]] - vaccine_data[vax_list[x]]
    x +=1

# %%
vaccine_data
# Out:
#                                        State  16/01/2021  18/01/2021  \
# 0                Andaman and Nicobar Islands         225         442
# 1                             Andhra Pradesh       18412       46680
# 2                          Arunachal Pradesh         829        2805
# 3                                      Assam        3528        5542
# 4                                      Bihar       18169       33389
# 5                                 Chandigarh         265         265
# 6                               Chhattisgarh        5592       10872
# 7   Dadra and Nagar Haveli and Daman and Diu         123         123
# 8                                      Delhi        4319        7968
# 9                                        Goa         426         426
# 10                                   Gujarat       10787       10787
# 11                                   Haryana        5589       17642
# 12                          Himachal Pradesh        1517        4817
# ...

# %%
vaccine_data['State']
# Out:
# 0                  Andaman and Nicobar Islands
# 1                               Andhra Pradesh
# 2                            Arunachal Pradesh
# 3                                        Assam
# 4                                        Bihar
# 5                                   Chandigarh
# 6                                 Chhattisgarh
# 7     Dadra and Nagar Haveli and Daman and Diu
# 8                                        Delhi
# 9                                          Goa
# 10                                     Gujarat
# 11                                     Haryana
# 12                            Himachal Pradesh
# 13                           Jammu and Kashmir
# 14                                   Jharkhand
# 15                                   Karnataka
# 16                                      Kerala
# 17                                      Ladakh
# 18                                 Lakshadweep
# 19                              Madhya Pradesh
# ...

# %%
state_index = 20

# %%
vaccine_data
# Out:
#                                        State  16/01/2021  18/01/2021  \
# 0                Andaman and Nicobar Islands         225         442
# 1                             Andhra Pradesh       18412       46680
# 2                          Arunachal Pradesh         829        2805
# 3                                      Assam        3528        5542
# 4                                      Bihar       18169       33389
# 5                                 Chandigarh         265         265
# 6                               Chhattisgarh        5592       10872
# 7   Dadra and Nagar Haveli and Daman and Diu         123         123
# 8                                      Delhi        4319        7968
# 9                                        Goa         426         426
# 10                                   Gujarat       10787       10787
# 11                                   Haryana        5589       17642
# 12                          Himachal Pradesh        1517        4817
# ...

# %%
state = vaccine_data.iloc[state_index:state_index + 1,130:]

# %%
state = state.T

# %%
state = state.reset_index()

# %%
state = state.rename(columns = {'index' : 'day', state_index: 'doses'})

# %%
plt.plot(state)

# %%
state['doses'].sum()
# Out:
# 21194105

# %%
type(state['doses'])
# Out:
# pandas.core.series.Series

# %%
type(state)
# Out:
# pandas.core.frame.DataFrame
