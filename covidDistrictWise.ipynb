# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame as df
from datetime import datetime
import numpy as np

# %%
folder = "c:/PY-ML/data/covid2405/"
file = folder + "district_wise.csv"

# %%
df = pd.read_csv(file)

# %%
df.columns
# Out:
# Index(['SlNo', 'State_Code', 'State', 'District_Key', 'District', 'Confirmed',
#        'Active', 'Recovered', 'Deceased', 'Migrated_Other', 'Delta_Confirmed',
#        'Delta_Active', 'Delta_Recovered', 'Delta_Deceased', 'District_Notes',
#        'Last_Updated'],
#       dtype='object')

# %%
df
# Out:
#      SlNo State_Code                        State  \
# 0       0         UN             State Unassigned
# 1       1         AN  Andaman and Nicobar Islands
# 2       2         AN  Andaman and Nicobar Islands
# 3       3         AN  Andaman and Nicobar Islands
# 4       0         AP               Andhra Pradesh
# ..    ...        ...                          ...
# 796   760         TG                    Telangana
# 797   761         TR                      Tripura
# 798   762         UP                Uttar Pradesh
# 799   763         UT                  Uttarakhand
# 800   764         WB                  West Bengal
#
#                     District_Key                  District  Confirmed  Active  \
# 0                  UN_Unassigned                Unassigned          0       0
# 1                    AN_Nicobars                  Nicobars          0       0
# 2    AN_North and Middle Andaman  North and Middle Andaman          1       0
# ...

# %%
confirm = df[['District','Confirmed']]

# %%
confirm = confirm.reset_index('District')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a8ef5b0facf7> in <module>
# ----> 1 confirm = confirm.reset_index('District')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4972             if not isinstance(level, (tuple, list)):
#    4973                 level = [level]
# -> 4974             level = [self.index._get_level_number(lev) for lev in level]
#    4975             if len(level) < self.index.nlevels:
#    4976                 new_index = self.index.droplevel(level)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    4972             if not isinstance(level, (tuple, list)):
#    4973                 level = [level]
# -> 4974             level = [self.index._get_level_number(lev) for lev in level]
# ...

# %%
confirm
