# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame as df
from datetime import datetime
import numpy as np
import covidutil as cu

# %%
#create file path

folder = "c:/PY-ML/data/covid1906/"
file = folder + "states.csv"

# %%
#create dataframe
df = pd.read_csv(file)

# %%
df
# Out:
#              Date          State  Confirmed  Recovered  Deceased  Other  \
# 0      2020-01-30         Kerala          1          0         0      0
# 1      2020-01-30          India          1          0         0      0
# 2      2020-02-02         Kerala          2          0         0      0
# 3      2020-02-02          India          2          0         0      0
# 4      2020-02-03         Kerala          3          0         0      0
# ...           ...            ...        ...        ...       ...    ...
# 16749  2021-06-20        Tripura      62146      57025       643     23
# 16750  2021-06-20          India   29912302   28800665    387215  11764
# 16751  2021-06-20  Uttar Pradesh    1704139    1677050     22132      0
# 16752  2021-06-20    Uttarakhand     338644     322681      7035   5792
# 16753  2021-06-20    West Bengal    1481707    1441343     17348      0
#
#             Tested
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
df['Date'] = pd.to_datetime(df["Date"])
df['Day'] = df['Date'].dt.day_name()
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Active'] = df['Confirmed'] - df['Recovered'] - df['Deceased']

# %%
state_list = list(df['State'].unique())

# %%
len(state_list)
# Out:
# 38

# %%
def get_state(data,state):
    st = data[data['State'] == state].reset_index(drop = True)
    return st

# %%
all_state_data = []
for i in state_list:
    data = get_state(df,i)
    all_state_data.append(data[:])

# %%
#subplot of all states
for i in range(0,10):
    plt.style.use("grayscale")
    
    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize = (20,3),sharex = True)
    
    plt.ticklabel_format(style = ('scientific'))
    plt.ticklabel_format(style = ('scientific'))
    ax1.plot(all_state_data[i]['Confirmed'])
    ax1.set_title(state_list[i] + ' Confirmed')
    ax1.set_xlabel('days')
    ax1.set_ylabel('Confirmed')
    
    plt.ticklabel_format(style = ('scientific'))
    ax2.plot(all_state_data[i]['Deceased'])
    ax2.set_title(state_list[i] + ' Deceased')
    ax2.set_xlabel('days')
    ax2.set_ylabel('Deceased')
    
    plt.ticklabel_format(style = ('scientific'))
    ax3.plot(all_state_data[i]['Recovered'])
    ax3.set_title(state_list[i] + ' Recovered')
    ax3.set_xlabel('days')
    ax3.set_ylabel('Recovered')
    
    plt.ticklabel_format(style = ('scientific'))
    ax4.ticklabel_format(style = 'plain')
    ax4.plot(all_state_data[i]['Active'])
    ax4.set_title(state_list[i] + ' Active')
    ax4.set_xlabel('days')
    ax4.set_ylabel('Active')

# %%
for i in range(11,20):
    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize = (13,3),sharex = True)
    ax1.ticklabel_format(style = 'plain')
    ax1.plot(all_state_data[i]['Confirmed'])
    ax1.set_title(state_list[i] + ' Confirmed')
    ax1.set_xlabel('days')
    ax1.set_ylabel('Confirmed')
          
    ax2.plot(all_state_data[i]['Deceased'])
    ax2.set_title(state_list[i] + ' Deceased')
    ax2.set_xlabel('days')
    ax2.set_ylabel('Deceased')

    ax3.plot(all_state_data[i]['Recovered'])
    ax3.set_title(state_list[i] + ' Recovered')
    ax3.set_xlabel('days')
    ax3.set_ylabel('Recovered')
    
    ax4.ticklabel_format(style = 'plain')
    ax4.plot(all_state_data[i]['Active'])
    ax4.set_title(state_list[i] + ' Active')
    ax4.set_xlabel('days')
    ax4.set_ylabel('Active')

# %%
for i in range(21,30):
    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize = (13,3),sharex = True)
    ax1.ticklabel_format(style = 'plain')
    ax1.plot(all_state_data[i]['Confirmed'])
    ax1.set_title(state_list[i] + ' Confirmed')
    ax1.set_xlabel('days')
    ax1.set_ylabel('Confirmed')
          
    ax2.plot(all_state_data[i]['Deceased'])
    ax2.set_title(state_list[i] + ' Deceased')
    ax2.set_xlabel('days')
    ax2.set_ylabel('Deceased')

    ax3.plot(all_state_data[i]['Recovered'])
    ax3.set_title(state_list[i] + ' Recovered')
    ax3.set_xlabel('days')
    ax3.set_ylabel('Recovered')
    
    ax4.ticklabel_format(style = 'plain')
    ax4.plot(all_state_data[i]['Active'])
    ax4.set_title(state_list[i] + ' Active')
    ax4.set_xlabel('days')
    ax4.set_ylabel('Active')

# %%
for i in range(31,37):
    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize = (13,3),sharex = True)
    ax1.ticklabel_format(style = 'plain')
    ax1.plot(all_state_data[i]['Confirmed'])
    ax1.set_title(state_list[i] + ' Confirmed')
    ax1.set_xlabel('days')
    ax1.set_ylabel('Confirmed')
          
    ax2.plot(all_state_data[i]['Deceased'])
    ax2.set_title(state_list[i] + ' Deceased')
    ax2.set_xlabel('days')
    ax2.set_ylabel('Deceased')

    ax3.plot(all_state_data[i]['Recovered'])
    ax3.set_title(state_list[i] + ' Recovered')
    ax3.set_xlabel('days')
    ax3.set_ylabel('Recovered')
    
    ax4.ticklabel_format(style = 'plain')
    ax4.plot(all_state_data[i]['Active'])
    ax4.set_title(state_list[i] + ' Active')
    ax4.set_xlabel('days')
    ax4.set_ylabel('Active')

# %% [markdown]
# ### NEXT

# %%
#dataframe of most recent date

df1 = df[df['Date'] == '2021-06-20'].reset_index(drop = True)

# %%
#drop row 'India'

df1 = df1.drop(33).reset_index(drop = True)

# %%
#states with max active cases

df1.nlargest(5, 'Confirmed').reset_index(drop = True)
# Out:
#         Date           State  Confirmed  Recovered  Deceased  Other  \
# 0 2021-06-20     Maharashtra    5963420    5710356    117356   3111
# 1 2021-06-20          Kerala    2809395    2690958     12061    436
# 2 2021-06-20       Karnataka    2806453    2645735     33883     22
# 3 2021-06-20      Tamil Nadu    2414680    2304885     31015      0
# 4 2021-06-20  Andhra Pradesh    1850563    1775176     12319      0
#
#        Tested     Day  Year  Month  Active
# 0  39312920.0  Sunday  2021      6  135708
# 1  21961374.0  Sunday  2021      6  106376
# 2  32739539.0  Sunday  2021      6  126835
# 3  30996798.0  Sunday  2021      6   78780
# 4  21050846.0  Sunday  2021      6   63068

# %%
#states with max recoveries

df1.nlargest(5, 'Recovered').reset_index(drop = True)
# Out:
#         Date           State  Confirmed  Recovered  Deceased  Other  \
# 0 2021-06-20     Maharashtra    5963420    5710356    117356   3111
# 1 2021-06-20          Kerala    2809395    2690958     12061    436
# 2 2021-06-20       Karnataka    2806453    2645735     33883     22
# 3 2021-06-20      Tamil Nadu    2414680    2304885     31015      0
# 4 2021-06-20  Andhra Pradesh    1850563    1775176     12319      0
#
#        Tested     Day  Year  Month  Active
# 0  39312920.0  Sunday  2021      6  135708
# 1  21961374.0  Sunday  2021      6  106376
# 2  32739539.0  Sunday  2021      6  126835
# 3  30996798.0  Sunday  2021      6   78780
# 4  21050846.0  Sunday  2021      6   63068

# %%
#states with max deaths


df1.nlargest(5, 'Deceased').reset_index(drop = True)
# Out:
#         Date          State  Confirmed  Recovered  Deceased  Other  \
# 0 2021-06-20    Maharashtra    5963420    5710356    117356   3111
# 1 2021-06-20      Karnataka    2806453    2645735     33883     22
# 2 2021-06-20     Tamil Nadu    2414680    2304885     31015      0
# 3 2021-06-20          Delhi    1432292    1405287     24914      0
# 4 2021-06-20  Uttar Pradesh    1704139    1677050     22132      0
#
#        Tested     Day  Year  Month  Active
# 0  39312920.0  Sunday  2021      6  135708
# 1  32739539.0  Sunday  2021      6  126835
# 2  30996798.0  Sunday  2021      6   78780
# 3  20774671.0  Sunday  2021      6    2091
# 4  55264433.0  Sunday  2021      6    4957

# %%
#states with max active cases

df1.nlargest(5, 'Active').reset_index(drop = True)
# Out:
#         Date           State  Confirmed  Recovered  Deceased  Other  \
# 0 2021-06-20     Maharashtra    5963420    5710356    117356   3111
# 1 2021-06-20       Karnataka    2806453    2645735     33883     22
# 2 2021-06-20          Kerala    2809395    2690958     12061    436
# 3 2021-06-20      Tamil Nadu    2414680    2304885     31015      0
# 4 2021-06-20  Andhra Pradesh    1850563    1775176     12319      0
#
#        Tested     Day  Year  Month  Active
# 0  39312920.0  Sunday  2021      6  135708
# 1  32739539.0  Sunday  2021      6  126835
# 2  21961374.0  Sunday  2021      6  106376
# 3  30996798.0  Sunday  2021      6   78780
# 4  21050846.0  Sunday  2021      6   63068

# %%
#creating death ratio variable to check likelihood of death

df1['death ratio'] = df1['Deceased']/df1['Confirmed'] * 100

# %%
#sorting by death-ratio 

df1.sort_values(by = 'death ratio', ascending = False)
# Out:
#          Date                                     State  Confirmed  Recovered  \
# 26 2021-06-20                                    Punjab     591762     567883
# 34 2021-06-20                               Uttarakhand     338644     322681
# 19 2021-06-20                               Maharashtra    5963420    5710356
# 24 2021-06-20                                  Nagaland      24248      21201
# 9  2021-06-20                                       Goa     164436     158178
# 7  2021-06-20                                     Delhi    1432292    1405287
# 20 2021-06-20                                 Meghalaya      45286      39919
# 0  2021-06-20               Andaman and Nicobar Islands       7394       7162
# 11 2021-06-20                          Himachal Pradesh     200410     194249
# 21 2021-06-20                                   Manipur      64065      53405
# 29 2021-06-20                                    Sikkim      19296      16056
# ...
